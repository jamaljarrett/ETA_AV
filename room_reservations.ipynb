# %%
import pandas as pd

# %%
room_df = pd.read_excel("room_reservations.xls")
test_room_df = pd.read_excel("Test_1.xls")
room_df.head()
# Out:
#   Unnamed: 0 Unnamed: 1  Unnamed: 2  Unnamed: 3               Unnamed: 4  \
# 0        NaN   Report:          NaN         NaN      AllOrdersByDate.rpt
# 1        NaN        NaN         NaN         NaN                      NaN
# 2        NaN     Scope:         NaN         NaN    All Service Providers
# 3        NaN        NaN         NaN         NaN                      NaN
# 4        NaN    Range:          NaN         NaN  04/01/2019 - 04/30/2020
#
#   Unnamed: 5 Unnamed: 6  Unnamed: 7  Unnamed: 8 Unnamed: 9  ...  Unnamed: 21  \
# 0        NaN        NaN         NaN         NaN        NaN  ...          NaN
# 1        NaN        NaN         NaN         NaN        NaN  ...          NaN
# 2        NaN        NaN         NaN         NaN        NaN  ...          NaN
# 3        NaN        NaN         NaN         NaN        NaN  ...          NaN
# 4        NaN        NaN         NaN         NaN        NaN  ...          NaN
#
# ...

# %%
room_df
# Out:
#       Unnamed: 0                                         Unnamed: 1  \
# 0            NaN                                           Report:
# 1            NaN                                                NaN
# 2            NaN                                             Scope:
# 3            NaN                                                NaN
# 4            NaN                                            Range:
# ...          ...                                                ...
# 65497        NaN                                                NaN
# 65498        NaN                                                NaN
# 65499        NaN                                                NaN
# 65500        NaN                                                NaN
# 65501        NaN  Totals do not include items marked as Market P...
#
#        Unnamed: 2  Unnamed: 3               Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# ...

# %%
test_room_df
# Out:
#     Unnamed: 0                                         Unnamed: 1  Unnamed: 2  \
# 0          NaN                                           Report:          NaN
# 1          NaN                                                NaN         NaN
# 2          NaN                                             Scope:         NaN
# 3          NaN                                                NaN         NaN
# 4          NaN                                            Range:          NaN
# ..         ...                                                ...         ...
# 119        NaN  Totals do not include items marked as Market P...         NaN
# 120        NaN                                                NaN         NaN
# 121        NaN                                                NaN         NaN
# 122        NaN                                                NaN         NaN
# 123        NaN           Powered By PeopleCube Resource Scheduler         NaN
#
# ...
